# %% [markdown]
# # Charity Funding Predictor - Optimization Attempt 2

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
# tf.keras.callbacks.ModelCheckpoint

#  read the charity_data.csv.
application_df = pd.read_csv("../Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
pd.options.display.max_columns = 50

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
df = application_df.drop(columns = ['EIN', 'NAME'])
df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = df['APPLICATION_TYPE'].value_counts() \
                                                        .loc[lambda x : x < 200] \
                                                        .index \
                                                        .to_list()
application_types_to_replace
# Out:
# ['T9', 'T13', 'T12', 'T2', 'T25', 'T14', 'T29', 'T15', 'T17']

# %%
# Replace in dataframe
for app in application_types_to_replace:
    df['APPLICATION_TYPE'] = df['APPLICATION_TYPE'].replace(app,"Other")

# %%
# Check to make sure binning was successful
df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
df['CLASSIFICATION'].value_counts().loc[lambda x: x>1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = df['CLASSIFICATION'].value_counts() \
                                                    .loc[lambda x : x < 1000] \
                                                    .index \
                                                    .to_list()
# Replace in dataframe
for cls in classifications_to_replace:
    df['CLASSIFICATION'] = df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
df.nunique()
# Out:
# APPLICATION_TYPE             9
# AFFILIATION                  6
# CLASSIFICATION               6
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
transformed_df = pd.get_dummies(df)
transformed_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# 1                         0                     0                    1
# 2                         0                     0                    0
# 3                         0                     0                    1
# 4                         0                     0                    1
# ...                     ...                   ...                  ...
# 34294                     0                     0                    0
# 34295                     0                     0                    0
# 34296                     0                     0                    1
# 34297                     0                     0                    0
# 34298                     0                     0                    1
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  \
# 0                        0                    0                    0
# 1                        0                    0                    0
# 2                        0                    1                    0
# 3                        0                    0                    0
# 4                        0                    0                    0
# ...                    ...                  ...                  ...
# 34294                    1                    0                    0
# 34295                    1                    0                    0
# 34296                    0                    0                    0
# 34297                    0                    1                    0
# 34298                    0                    0                    0
#
#        APPLICATION_TYPE_T7  APPLICATION_TYPE_T8  AFFILIATION_CompanySponsored  \
# 0                        0                    0                             0
# 1                        0                    0                             0
# 2                        0                    0                             1
# 3                        0                    0                             1
# 4                        0                    0                             0
# ...                    ...                  ...                           ...
# 34294                    0                    0                             0
# 34295                    0                    0                             1
# 34296                    0                    0                             1
# 34297                    0                    0                             0
# 34298                    0                    0                             0
#
#        AFFILIATION_Family/Parent  AFFILIATION_Independent  \
# 0                              0                        1
# 1                              0                        1
# 2                              0                        0
# 3                              0                        0
# 4                              0                        1
# ...                          ...                      ...
# 34294                          0                        1
# 34295                          0                        0
# 34296                          0                        0
# 34297                          0                        1
# 34298                          0                        1
#
#        AFFILIATION_National  AFFILIATION_Other  AFFILIATION_Regional  \
# 0                         0                  0                     0
# 1                         0                  0                     0
# 2                         0                  0                     0
# 3                         0                  0                     0
# 4                         0                  0                     0
# ...                     ...                ...                   ...
# 34294                     0                  0                     0
# 34295                     0                  0                     0
# 34296                     0                  0                     0
# 34297                     0                  0                     0
# 34298                     0                  0                     0
#
#        CLASSIFICATION_C1000  CLASSIFICATION_C1200  CLASSIFICATION_C2000  \
# 0                         1                     0                     0
# 1                         0                     0                     1
# 2                         0                     0                     0
# 3                         0                     0                     1
# 4                         1                     0                     0
# ...                     ...                   ...                   ...
# 34294                     1                     0                     0
# 34295                     0                     0                     0
# 34296                     0                     0                     1
# 34297                     0                     0                     0
# 34298                     1                     0                     0
#
#        CLASSIFICATION_C2100  CLASSIFICATION_C3000  CLASSIFICATION_Other  \
# 0                         0                     0                     0
# 1                         0                     0                     0
# 2                         0                     1                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# ...                     ...                   ...                   ...
# 34294                     0                     0                     0
# 34295                     0                     1                     0
# 34296                     0                     0                     0
# 34297                     0                     1                     0
# 34298                     0                     0                     0
#
#        USE_CASE_CommunityServ  USE_CASE_Heathcare  USE_CASE_Other  \
# 0                           0                   0               0
# 1                           0                   0               0
# 2                           0                   0               0
# 3                           0                   0               0
# 4                           0                   1               0
# ...                       ...                 ...             ...
# 34294                       0                   0               0
# 34295                       0                   0               0
# 34296                       0                   0               0
# 34297                       0                   0               0
# 34298                       0                   0               0
#
#        USE_CASE_Preservation  USE_CASE_ProductDev  ORGANIZATION_Association  \
# 0                          0                    1                         1
# 1                          1                    0                         0
# 2                          0                    1                         1
# 3                          1                    0                         0
# 4                          0                    0                         0
# ...                      ...                  ...                       ...
# 34294                      0                    1                         1
# 34295                      0                    1                         1
# 34296                      1                    0                         1
# 34297                      0                    1                         1
# 34298                      1                    0                         0
#
#        ORGANIZATION_Co-operative  ORGANIZATION_Corporation  \
# 0                              0                         0
# 1                              1                         0
# 2                              0                         0
# 3                              0                         0
# 4                              0                         0
# ...                          ...                       ...
# 34294                          0                         0
# 34295                          0                         0
# 34296                          0                         0
# 34297                          0                         0
# 34298                          1                         0
#
#        ORGANIZATION_Trust  INCOME_AMT_0  INCOME_AMT_1-9999  \
# 0                       0             1                  0
# 1                       0             0                  1
# 2                       0             1                  0
# 3                       1             0                  0
# 4                       1             0                  0
# ...                   ...           ...                ...
# 34294                   0             1                  0
# 34295                   0             1                  0
# 34296                   0             1                  0
# 34297                   0             1                  0
# 34298                   0             0                  0
#
#        INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  INCOME_AMT_10M-50M  \
# 0                           0                         0                   0
# 1                           0                         0                   0
# 2                           0                         0                   0
# 3                           1                         0                   0
# 4                           0                         1                   0
# ...                       ...                       ...                 ...
# 34294                       0                         0                   0
# 34295                       0                         0                   0
# 34296                       0                         0                   0
# 34297                       0                         0                   0
# 34298                       0                         0                   0
#
#        INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  INCOME_AMT_50M+  \
# 0                     0                       0                0
# 1                     0                       0                0
# 2                     0                       0                0
# 3                     0                       0                0
# 4                     0                       0                0
# ...                 ...                     ...              ...
# 34294                 0                       0                0
# 34295                 0                       0                0
# 34296                 0                       0                0
# 34297                 0                       0                0
# 34298                 1                       0                0
#
#        INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0                      0                         1                         0
# 1                      0                         1                         0
# 2                      0                         1                         0
# 3                      0                         1                         0
# 4                      0                         1                         0
# ...                  ...                       ...                       ...
# 34294                  0                         1                         0
# 34295                  0                         1                         0
# 34296                  0                         1                         0
# 34297                  0                         1                         0
# 34298                  0                         1                         0
#
# [34299 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays

X = transformed_df.drop(columns = 'IS_SUCCESSFUL')
y = transformed_df['IS_SUCCESSFUL']

# %%
# Split the preprocessed data into a training and testing dataset

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 75)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((25724, 43), (8575, 43), (25724,), (8575,))

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=200, activation="sigmoid", input_dim=43))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=100, activation="sigmoid"))

# Third hidden layer
nn_model.add(tf.keras.layers.Dense(units=30, activation="sigmoid"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 200)               8800
#
#  dense_1 (Dense)             (None, 100)               20100
#
#  dense_2 (Dense)             (None, 30)                3030
#
#  dense_3 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 31,961
# Trainable params: 31,961
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
nn_model

# %%
# Train the model

fit_model = nn_model.fit(X_train_scaled, y_train, epochs=150, verbose = 1)
# Out:
# Epoch 1/150
# 804/804 [==============================] - 1s 695us/step - loss: 0.5978 - accuracy: 0.6986
# Epoch 2/150
# 804/804 [==============================] - 1s 697us/step - loss: 0.5741 - accuracy: 0.7198
# Epoch 3/150
# 804/804 [==============================] - 1s 691us/step - loss: 0.5647 - accuracy: 0.7236
# Epoch 4/150
# 804/804 [==============================] - 1s 693us/step - loss: 0.5619 - accuracy: 0.7254
# Epoch 5/150
# 804/804 [==============================] - 1s 692us/step - loss: 0.5605 - accuracy: 0.7264
# Epoch 6/150
# 804/804 [==============================] - 1s 699us/step - loss: 0.5583 - accuracy: 0.7268
# Epoch 7/150
# 804/804 [==============================] - 1s 712us/step - loss: 0.5571 - accuracy: 0.7272
# Epoch 8/150
# 804/804 [==============================] - 1s 726us/step - loss: 0.5560 - accuracy: 0.7271
# Epoch 9/150
# 804/804 [==============================] - 1s 739us/step - loss: 0.5558 - accuracy: 0.7278
# Epoch 10/150
# 804/804 [==============================] - 1s 736us/step - loss: 0.5545 - accuracy: 0.7276
# Epoch 11/150
# 804/804 [==============================] - 1s 733us/step - loss: 0.5541 - accuracy: 0.7288
# Epoch 12/150
# 804/804 [==============================] - 1s 732us/step - loss: 0.5535 - accuracy: 0.7282
# Epoch 13/150
# 804/804 [==============================] - 1s 760us/step - loss: 0.5534 - accuracy: 0.7294
# Epoch 14/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5522 - accuracy: 0.7299
# Epoch 15/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5519 - accuracy: 0.7297
# Epoch 16/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5517 - accuracy: 0.7271
# Epoch 17/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5510 - accuracy: 0.7297
# Epoch 18/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5505 - accuracy: 0.7303
# Epoch 19/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5501 - accuracy: 0.7290
# Epoch 20/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5494 - accuracy: 0.7300
# Epoch 21/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5491 - accuracy: 0.7312
# Epoch 22/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5486 - accuracy: 0.7286
# Epoch 23/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5484 - accuracy: 0.7311
# Epoch 24/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5482 - accuracy: 0.7310
# Epoch 25/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5479 - accuracy: 0.7310
# Epoch 26/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5472 - accuracy: 0.7311
# Epoch 27/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5467 - accuracy: 0.7303
# Epoch 28/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5464 - accuracy: 0.7304
# Epoch 29/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5462 - accuracy: 0.7317
# Epoch 30/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5466 - accuracy: 0.7320
# Epoch 31/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5457 - accuracy: 0.7304
# Epoch 32/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5451 - accuracy: 0.7317
# Epoch 33/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.
150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5344 - accuracy: 0.7385
# Epoch 101/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5341 - accuracy: 0.7391
# Epoch 102/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5341 - accuracy: 0.7384
# Epoch 103/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5342 - accuracy: 0.7388
# Epoch 104/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5341 - accuracy: 0.7389
# Epoch 105/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5340 - accuracy: 0.7388
# Epoch 106/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.7388
# Epoch 107/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5340 - accuracy: 0.7390
# Epoch 108/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5341 - accuracy: 0.7381
# Epoch 109/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5337 - accuracy: 0.7390
# Epoch 110/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5337 - accuracy: 0.7390
# Epoch 111/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5336 - accuracy: 0.7393
# Epoch 112/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5336 - accuracy: 0.7396
# Epoch 113/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5336 - accuracy: 0.7390
# Epoch 114/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5335 - accuracy: 0.7386
# Epoch 115/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5334 - accuracy: 0.7391
# Epoch 116/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5335 - accuracy: 0.7393
# Epoch 117/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5333 - accuracy: 0.7391
# Epoch 118/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5333 - accuracy: 0.7395
# Epoch 119/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5330 - accuracy: 0.7392
# Epoch 120/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5332 - accuracy: 0.7393
# Epoch 121/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5329 - accuracy: 0.7393
# Epoch 122/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5330 - accuracy: 0.7402
# Epoch 123/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5329 - accuracy: 0.7394
# Epoch 124/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5328 - accuracy: 0.7387
# Epoch 125/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5330 - accuracy: 0.7395
# Epoch 126/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5328 - accuracy: 0.7393
# Epoch 127/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5327 - accuracy: 0.7394
# Epoch 128/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5325 - accuracy: 0.7405
# Epoch 129/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5326 - accuracy: 0.7393
# Epoch 130/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5325 - accuracy: 0.7387
# Epoch 131/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5325 - accuracy: 0.7393
# Epoch 132/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5323 - accuracy: 0.7398
# Epoch 133/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5325 - accuracy: 0.7395
# Epoch 134/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5324 - accuracy: 0.7397
# Epoch 135/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5324 - accuracy: 0.7391
# Epoch 136/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5321 - accuracy: 0.7395
# Epoch 137/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5323 - accuracy: 0.7396
# Epoch 138/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5322 - accuracy: 0.7395
# Epoch 139/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5322 - accuracy: 0.7403
# Epoch 140/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5320 - accuracy: 0.7397
# Epoch 141/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5323 - accuracy: 0.7393
# Epoch 142/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5321 - accuracy: 0.7398
# Epoch 143/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5321 - accuracy: 0.7398
# Epoch 144/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5320 - accuracy: 0.7398
# Epoch 145/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5318 - accuracy: 0.7392
# Epoch 146/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5319 - accuracy: 0.7396
# Epoch 147/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5321 - accuracy: 0.7391
# Epoch 148/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5318 - accuracy: 0.7394
# Epoch 149/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5318 - accuracy: 0.7390
# Epoch 150/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5316 - accuracy: 0.7398

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5726 - accuracy: 0.7349 - 319ms/epoch - 1ms/step
# Loss: 0.5725563764572144, Accuracy: 0.7349271178245544

# %%
# Export our model to HDF5 file

nn_model.save('../HDF5_Files/AlphabetSoupCharity_OptimizationAttempt2.h5')

# %%
history_df = pd.DataFrame(fit_model.history)

history_df.index += 1

history_df.plot(y='loss', color = 'red')
plt.xlabel('Epoch Index')
plt.ylabel('Loss')
plt.title('Training Loss Graph')
plt.legend (loc = 'center right')
plt.savefig("../Images/A2_Model_Loss.png")


history_df.plot(y='accuracy', color = 'green')
plt.xlabel('Epoch Index')
plt.ylabel('Accuracy')
plt.title('Training Accuracy Graph')
plt.legend (loc = 'center right')
plt.savefig("../Images/A2_Model_Accuracy.png")


plt.figure(figsize = (15,5))
plt.plot(history_df['loss'], color='red', label='loss', )
plt.plot(history_df['accuracy'], color='green', label='accuracy')
plt.xlim([0, 152])
plt.ylim([0.45, 0.8])
plt.xlabel('Epoch Index')
plt.ylabel('Accuracy/Loss')
plt.title('Model Training Accuracy/Loss Graph')
plt.legend(loc = 'center right')
plt.savefig("../Images/A2_ModelAccuracy_Loss.png")
plt.show()
