# %% [markdown]
# # Charity Funding Predictor

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
# tf.keras.callbacks.ModelCheckpoint

#  read the charity_data.csv.
application_df = pd.read_csv("../Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
pd.options.display.max_columns = 50

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
df = application_df.drop(columns = ['EIN', 'NAME'])
df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = df['APPLICATION_TYPE'].value_counts() \
                                                        .loc[lambda x : x < 200] \
                                                        .index \
                                                        .to_list()
application_types_to_replace
# Out:
# ['T9', 'T13', 'T12', 'T2', 'T25', 'T14', 'T29', 'T15', 'T17']

# %%
# Replace in dataframe
for app in application_types_to_replace:
    df['APPLICATION_TYPE'] = df['APPLICATION_TYPE'].replace(app,"Other")

# %%
# Check to make sure binning was successful
df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
df['CLASSIFICATION'].value_counts().loc[lambda x: x>1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = df['CLASSIFICATION'].value_counts() \
                                                    .loc[lambda x : x < 1000] \
                                                    .index \
                                                    .to_list()
# Replace in dataframe
for cls in classifications_to_replace:
    df['CLASSIFICATION'] = df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
df.nunique()
# Out:
# APPLICATION_TYPE             9
# AFFILIATION                  6
# CLASSIFICATION               6
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
transformed_df = pd.get_dummies(df)
transformed_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# 1                         0                     0                    1
# 2                         0                     0                    0
# 3                         0                     0                    1
# 4                         0                     0                    1
# ...                     ...                   ...                  ...
# 34294                     0                     0                    0
# 34295                     0                     0                    0
# 34296                     0                     0                    1
# 34297                     0                     0                    0
# 34298                     0                     0                    1
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  \
# 0                        0                    0                    0
# 1                        0                    0                    0
# 2                        0                    1                    0
# 3                        0                    0                    0
# 4                        0                    0                    0
# ...                    ...                  ...                  ...
# 34294                    1                    0                    0
# 34295                    1                    0                    0
# 34296                    0                    0                    0
# 34297                    0                    1                    0
# 34298                    0                    0                    0
#
#        APPLICATION_TYPE_T7  APPLICATION_TYPE_T8  AFFILIATION_CompanySponsored  \
# 0                        0                    0                             0
# 1                        0                    0                             0
# 2                        0                    0                             1
# 3                        0                    0                             1
# 4                        0                    0                             0
# ...                    ...                  ...                           ...
# 34294                    0                    0                             0
# 34295                    0                    0                             1
# 34296                    0                    0                             1
# 34297                    0                    0                             0
# 34298                    0                    0                             0
#
#        AFFILIATION_Family/Parent  AFFILIATION_Independent  \
# 0                              0                        1
# 1                              0                        1
# 2                              0                        0
# 3                              0                        0
# 4                              0                        1
# ...                          ...                      ...
# 34294                          0                        1
# 34295                          0                        0
# 34296                          0                        0
# 34297                          0                        1
# 34298                          0                        1
#
#        AFFILIATION_National  AFFILIATION_Other  AFFILIATION_Regional  \
# 0                         0                  0                     0
# 1                         0                  0                     0
# 2                         0                  0                     0
# 3                         0                  0                     0
# 4                         0                  0                     0
# ...                     ...                ...                   ...
# 34294                     0                  0                     0
# 34295                     0                  0                     0
# 34296                     0                  0                     0
# 34297                     0                  0                     0
# 34298                     0                  0                     0
#
#        CLASSIFICATION_C1000  CLASSIFICATION_C1200  CLASSIFICATION_C2000  \
# 0                         1                     0                     0
# 1                         0                     0                     1
# 2                         0                     0                     0
# 3                         0                     0                     1
# 4                         1                     0                     0
# ...                     ...                   ...                   ...
# 34294                     1                     0                     0
# 34295                     0                     0                     0
# 34296                     0                     0                     1
# 34297                     0                     0                     0
# 34298                     1                     0                     0
#
#        CLASSIFICATION_C2100  CLASSIFICATION_C3000  CLASSIFICATION_Other  \
# 0                         0                     0                     0
# 1                         0                     0                     0
# 2                         0                     1                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# ...                     ...                   ...                   ...
# 34294                     0                     0                     0
# 34295                     0                     1                     0
# 34296                     0                     0                     0
# 34297                     0                     1                     0
# 34298                     0                     0                     0
#
#        USE_CASE_CommunityServ  USE_CASE_Heathcare  USE_CASE_Other  \
# 0                           0                   0               0
# 1                           0                   0               0
# 2                           0                   0               0
# 3                           0                   0               0
# 4                           0                   1               0
# ...                       ...                 ...             ...
# 34294                       0                   0               0
# 34295                       0                   0               0
# 34296                       0                   0               0
# 34297                       0                   0               0
# 34298                       0                   0               0
#
#        USE_CASE_Preservation  USE_CASE_ProductDev  ORGANIZATION_Association  \
# 0                          0                    1                         1
# 1                          1                    0                         0
# 2                          0                    1                         1
# 3                          1                    0                         0
# 4                          0                    0                         0
# ...                      ...                  ...                       ...
# 34294                      0                    1                         1
# 34295                      0                    1                         1
# 34296                      1                    0                         1
# 34297                      0                    1                         1
# 34298                      1                    0                         0
#
#        ORGANIZATION_Co-operative  ORGANIZATION_Corporation  \
# 0                              0                         0
# 1                              1                         0
# 2                              0                         0
# 3                              0                         0
# 4                              0                         0
# ...                          ...                       ...
# 34294                          0                         0
# 34295                          0                         0
# 34296                          0                         0
# 34297                          0                         0
# 34298                          1                         0
#
#        ORGANIZATION_Trust  INCOME_AMT_0  INCOME_AMT_1-9999  \
# 0                       0             1                  0
# 1                       0             0                  1
# 2                       0             1                  0
# 3                       1             0                  0
# 4                       1             0                  0
# ...                   ...           ...                ...
# 34294                   0             1                  0
# 34295                   0             1                  0
# 34296                   0             1                  0
# 34297                   0             1                  0
# 34298                   0             0                  0
#
#        INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  INCOME_AMT_10M-50M  \
# 0                           0                         0                   0
# 1                           0                         0                   0
# 2                           0                         0                   0
# 3                           1                         0                   0
# 4                           0                         1                   0
# ...                       ...                       ...                 ...
# 34294                       0                         0                   0
# 34295                       0                         0                   0
# 34296                       0                         0                   0
# 34297                       0                         0                   0
# 34298                       0                         0                   0
#
#        INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  INCOME_AMT_50M+  \
# 0                     0                       0                0
# 1                     0                       0                0
# 2                     0                       0                0
# 3                     0                       0                0
# 4                     0                       0                0
# ...                 ...                     ...              ...
# 34294                 0                       0                0
# 34295                 0                       0                0
# 34296                 0                       0                0
# 34297                 0                       0                0
# 34298                 1                       0                0
#
#        INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0                      0                         1                         0
# 1                      0                         1                         0
# 2                      0                         1                         0
# 3                      0                         1                         0
# 4                      0                         1                         0
# ...                  ...                       ...                       ...
# 34294                  0                         1                         0
# 34295                  0                         1                         0
# 34296                  0                         1                         0
# 34297                  0                         1                         0
# 34298                  0                         1                         0
#
# [34299 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays

X = transformed_df.drop(columns = 'IS_SUCCESSFUL')
y = transformed_df['IS_SUCCESSFUL']

# %%
# Split the preprocessed data into a training and testing dataset

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 75)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((25724, 43), (8575, 43), (25724,), (8575,))

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=43))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=30, activation="tanh"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 5,981
# Trainable params: 5,981
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
nn_model

# %%
# Train the model

# Include the epoch in the file name (uses `str.format`)
checkpoint_path = "training/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

batch_size = 32

# Create a callback that saves the model's weights every 5 epochs
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True, 
                                                 save_freq = 5*batch_size, 
                                                 verbose=1)

# Save the weights using the `checkpoint_path` format
nn_model.save_weights(checkpoint_path.format(epoch=0))

# Train the model with the new callback
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50, 
                         batch_size=batch_size,
                        validation_data=(X_test, y_test), callbacks=[cp_callback], verbose = 1)
# Out:
# Epoch 1/50
# 120/804 [===>..........................] - ETA: 0s - loss: 0.6063 - accuracy: 0.6945
# Epoch 00001: saving model to training\cp-0001.ckpt
# 297/804 [==========>...................] - ETA: 0s - loss: 0.5800 - accuracy: 0.7168
# Epoch 00001: saving model to training\cp-0001.ckpt
# 421/804 [==============>...............] - ETA: 0s - loss: 0.5777 - accuracy: 0.7173
# Epoch 00001: saving model to training\cp-0001.ckpt
# 599/804 [=====================>........] - ETA: 0s - loss: 0.5753 - accuracy: 0.7191
# Epoch 00001: saving model to training\cp-0001.ckpt
# 756/804 [===========================>..] - ETA: 0s - loss: 0.5721 - accuracy: 0.7205
# Epoch 00001: saving model to training\cp-0001.ckpt
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5723 - accuracy: 0.7197 - val_loss: 0.7537 - val_accuracy: 0.5254
# Epoch 2/50
#  81/804 [==>...........................] - ETA: 0s - loss: 0.5457 - accuracy: 0.7373
# Epoch 00002: saving model to training\cp-0002.ckpt
# 278/804 [=========>....................] - ETA: 0s - loss: 0.5553 - accuracy: 0.7279
# Epoch 00002: saving model to training\cp-0002.ckpt
# 452/804 [===============>..............] - ETA: 0s - loss: 0.5536 - accuracy: 0.7289
# Epoch 00002: saving model to training\cp-0002.ckpt
# 624/804 [======================>.......] - ETA: 0s - loss: 0.5574 - accuracy: 0.7260
# Epoch 00002: saving model to training\cp-0002.ckpt
# 751/804 [===========================>..] - ETA: 0s - loss: 0.5591 - accuracy: 0.7253
# Epoch 00002: saving model to training\cp-0002.ckpt
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5584 - accuracy: 0.7264 - val_loss: 0.7529 - val_accuracy: 0.5254
# Epoch 3/50
#  79/804 [=>............................] - ETA: 0s - loss: 0.5457 - accuracy: 0.7413
# Epoch 00003: saving model to training\cp-0003.ckpt
# 308/804 [==========>...................] - ETA: 0s - loss: 0.5508 - accuracy: 0.7342
# Epoch 00003: saving model to training\cp-0003.ckpt
# 420/804 [==============>...............] - ETA: 0s - loss: 0.5506 - accuracy: 0.7324
# Epoch 00003: saving model to training\cp-0003.ckpt
# 550/804 [===================>..........] - ETA: 0s - loss: 0.5537 - accuracy: 0.7297
# Epoch 00003: saving model to training\cp-0003.ckpt
# 783/804 [============================>.] - ETA: 0s - loss: 0.5541 - accuracy: 0.7295
# Epoch 00003: saving model to training\cp-0003.ckpt
# 804/804 [==============================] - 1s 921us/step - loss: 0.5543 - accuracy: 0.7294 - val_loss: 0.7190 - val_accuracy: 0.4746
# Epoch 4/50
#  82/804 [==>...........................] - ETA: 0s - loss: 0.5516 - accuracy: 0.7309
# Epoch 00004: saving model to training\cp-0004.ckpt
# 307/804 [==========>...................] - ETA: 0s - loss: 0.5493 - accuracy: 0.7318
# Epoch 00004: saving model to training\cp-0004.ckpt
# 431/804 [===============>..............] - ETA: 0s - loss: 0.5521 - accuracy: 0.7310
# Epoch 00004: saving model to training\cp-0004.ckpt
# 627/804 [======================>.......] - ETA: 0s - loss: 0.5515 - accuracy: 0.7302
# Epoch 00004: saving model to training\cp-0004.ckpt
# 765/804 [===========================>..] - ETA: 0s - loss: 0.5531 - accuracy: 0.7286
# Epoch 00004: saving model to training\cp-0004.ckpt
# 804/804 [==============================] - 1s 898us/step - loss: 0.5540 - accuracy: 0.7275 - val_loss: 0.7153 - val_accuracy: 0.4746
# Epoch 5/50
#  69/804 [=>............................] - ETA: 0s - loss: 0.5585 - accuracy: 0.7097
# Epoch 00005: saving model to training\cp-0005.ckpt
# 300/804 [==========>...................] - ETA: 0s - loss: 0.5526 - accuracy: 0.7259
# Epoch 00005: saving model to training\cp-0005.ckpt
# 417/804 [==============>...............] - ETA: 0s - loss: 0.5526 - accuracy: 0.7257
# Epoch 00005: saving model to training\cp-0005.ckpt
# 581/804 [====================>.........] - ETA: 0s - loss: 0.5493 - accuracy: 0.7302
# Epoch 00005: saving model to training\cp-0005.ckpt
# 771/804 [===========================>..] - ETA: 0s - loss: 0.5519 - accuracy: 0.7285
# Epoch 00005: saving model to training\cp-0005.ckpt
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5520 - accuracy: 0.7289 - val_loss: 0.7554 - val_accuracy: 0.4746
# Epoch 6/50
# 124/804 [===>..........................] - ETA: 1s - loss: 0.5532 - accuracy: 0.7223
# Epoch 00006: saving model to training\cp-0006.ckpt
# 292/804 [=========>....................] - ETA: 0s - loss: 0.5456 - accuracy: 0.7326
# Epoch 00006: saving model to training\cp-0006.ckpt
# 451/804 [===============>..............] - ETA: 0s - loss: 0.5463 - accuracy: 0.7327
# Epoch 00006: saving model to training\cp-0006.ckpt
# 608/804 [=====================>........] - ETA: 0s - loss: 0.5487 - accuracy: 0.7313
# Epoch 00006: saving model to training\cp-0006.ckpt
# 771/804 [===========================>..] - ETA: 0s - loss: 0.5506 - accuracy: 0.7304
# Epoch 00006: saving model to training\cp-0006.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5503 - accuracy: 0.7303 - val_loss: 0.7580 - val_accuracy: 0.4746
# Epoch 7/50
# 109/804 [===>..........................] - ETA: 0s - loss: 0.5569 - accuracy: 0.7248
# Epoch 00007: saving model to training\cp-0007.ckpt
# 295/804 [==========>...................] - ETA: 0s - loss: 0.5524 - accuracy: 0.7266
# Epoch 00007: saving model to training\cp-0007.ckpt
# 428/804 [==============>...............] - ETA: 0s - loss: 0.5518 - accuracy: 0.7279
# Epoch 00007: saving model to training\cp-0007.ckpt
# 607/804 [=====================>........] - ETA: 0s - loss: 0.5491 - accuracy: 0.7318
# Epoch 00007: saving model to training\cp-0007.ckpt
# 772/804 [===========================>..] - ETA: 0s - loss: 0.5502 - accuracy: 0.7309
# Epoch 00007: saving model to training\cp-0007.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5497 - accuracy: 0.7309 - val_loss: 0.6941 - val_accuracy: 0.5254
# Epoch 8/50
# 121/804 [===>..........................] - ETA: 1s - loss: 0.5437 - accuracy: 0.7299
# Epoch 00008: saving model to training\cp-0008.ckpt
# 290/804 [=========>....................] - ETA: 0s - loss: 0.5442 - accuracy: 0.7322
# Epoch 00008: saving model to training\cp-0008.ckpt
# 426/804 [==============>...............] - ETA: 0s - loss: 0.5425 - accuracy: 0.7352
# Epoch 00008: saving model to training\cp-0008.ckpt
# 603/804 [=====================>........] - ETA: 0s - loss: 0.5441 - accuracy: 0.7339
# Epoch 00008: saving model to training\cp-0008.ckpt
# 769/804 [===========================>..] - ETA: 0s - loss: 0.5477 - accuracy: 0.7309
# Epoch 00008: saving model to training\cp-0008.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5492 - accuracy: 0.7297 - val_loss: 0.7233 - val_accuracy: 0.4746
# Epoch 9/50
#  94/804 [==>...........................] - ETA: 0s - loss: 0.5344 - accuracy: 0.7400
# Epoch 00009: saving model to training\cp-0009.ckpt
# 265/804 [========>.....................] - ETA: 0s - loss: 0.5408 - accuracy: 0.7353
# Epoch 00009: saving model to training\cp-0009.ckpt
# 431/804 [===============>..............] - ETA: 0s - loss: 0.5434 - accuracy: 0.7328
# Epoch 00009: saving model to training\cp-0009.ckpt
# 596/804 [=====================>........] - ETA: 0s - loss: 0.5444 - accuracy: 0.7329
# Epoch 00009: saving model to training\cp-0009.ckpt
# 747/804 [==========================>...] - ETA: 0s - loss: 0.5471 - accuracy: 0.7323
# Epoch 00009: saving model to training\cp-0009.ckpt
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5481 - accuracy: 0.7317 - val_loss: 0.7232 - val_accuracy: 0.4746
# Epoch 10/50
# 108/804 [===>..........................] - ETA: 0s - loss: 0.5467 - accuracy: 0.7309
# Epoch 00010: saving model to training\cp-0010.ckpt
# 266/804 [========>.....................] - ETA: 0s - loss: 0.5502 - accuracy: 0.7280
# Epoch 00010: saving model to training\cp-0010.ckpt
# 434/804 [===============>..............] - ETA: 0s - loss: 0.5486 - accuracy: 0.7303
# Epoch 00010: saving model to training\cp-0010.ckpt
# 584/804 [====================>.........] - ETA: 0s - loss: 0.5475 - accuracy: 0.7310
# Epoch 00010: saving model to training\cp-0010.ckpt
# 737/804 [==========================>...] - ETA: 0s - loss: 0.5493 - accuracy: 0.7294
# Epoch 00010: saving model to training\cp-0010.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5477 - accuracy: 0.7306 - val_loss: 0.7170 - val_accuracy: 0.4746
# Epoch 11/50
#  93/804 [==>...........................] - ETA: 1s - loss: 0.5473 - accuracy: 0.7329
# Epoch 00011: saving model to training\cp-0011.ckpt
# 278/804 [=========>....................] - ETA: 0s - loss: 0.5456 - accuracy: 0.7333
# Epoch 00011: saving model to training\cp-0011.ckpt
# 413/804 [==============>...............] - ETA: 0s - loss: 0.5451 - accuracy: 0.7325
# Epoch 00011: saving model to training\cp-0011.ckpt
# 591/804 [=====================>........] - ETA: 0s - loss: 0.5462 - accuracy: 0.7323
# Epoch 00011: saving model to training\cp-0011.ckpt
# 753/804 [===========================>..] - ETA: 0s - loss: 0.5471 - accuracy: 0.7317
# Epoch 00011: saving model to training\cp-0011.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5475 - accuracy: 0.7311 - val_loss: 0.6927 - val_accuracy: 0.5254
# Epoch 12/50
#  91/804 [==>...........................] - ETA: 1s - loss: 0.5460 - accuracy: 0.7297
# Epoch 00012: saving model to training\cp-0012.ckpt
# 266/804 [========>.....................] - ETA: 0s - loss: 0.5494 - accuracy: 0.7269
# Epoch 00012: saving model to training\cp-0012.ckpt
# 430/804 [===============>..............] - ETA: 0s - loss: 0.5456 - accuracy: 0.7319
# Epoch 00012: saving model to training\cp-0012.ckpt
# 592/804 [=====================>........] - ETA: 0s - loss: 0.5443 - accuracy: 0.7331
# Epoch 00012: saving model to training\cp-0012.ckpt
# 727/804 [==========================>...] - ETA: 0s - loss: 0.5440 - accuracy: 0.7345
# Epoch 00012: saving model to training\cp-0012.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5462 - accuracy: 0.7329 - val_loss: 0.6923 - val_accuracy: 0.5254
# Epoch 13/50
#  94/804 [==>...........................] - ETA: 1s - loss: 0.5415 - accuracy: 0.7337
# Epoch 00013: saving model to training\cp-0013.ckpt
# 244/804 [========>.....................] - ETA: 0s - loss: 0.5428 - accuracy: 0.7358
# Epoch 00013: saving model to training\cp-0013.ckpt
# 415/804 [==============>...............] - ETA: 0s - loss: 0.5434 - accuracy: 0.7364
# Epoch 00013: saving model to training\cp-0013.ckpt
# 564/804 [====================>.........] - ETA: 0s - loss: 0.5449 - accuracy: 0.7344
# Epoch 00013: saving model to training\cp-0013.ckpt
# 750/804 [==========================>...] - ETA: 0s - loss: 0.5473 - accuracy: 0.7326
# Epoch 00013: saving model to training\cp-0013.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5464 - accuracy: 0.7328 - val_loss: 0.6920 - val_accuracy: 0.5254
# Epoch 14/50
#  98/804 [==>...........................] - ETA: 1s - loss: 0.5403 - accuracy: 0.7296
# Epoch 00014: saving model to training\cp-0014.ckpt
# 255/804 [========>.....................] - ETA: 0s - loss: 0.5470 - accuracy: 0.7284
# Epoch 00014: saving model to training\cp-0014.ckpt
# 419/804 [==============>...............] - ETA: 0s - loss: 0.5485 - accuracy: 0.7289
# Epoch 00014: saving model to training\cp-0014.ckpt
# 573/804 [====================>.........] - ETA: 0s - loss: 0.5467 - accuracy: 0.7303
# Epoch 00014: saving model to training\cp-0014.ckpt
# 721/804 [=========================>....] - ETA: 0s - loss: 0.5470 - accuracy: 0.7301
# Epoch 00014: saving model to training\cp-0014.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5456 - accuracy: 0.7316 - val_loss: 0.6942 - val_accuracy: 0.4746
# Epoch 15/50
#  52/804 [>.............................] - ETA: 0s - loss: 0.5309 - accuracy: 0.7464
# Epoch 00015: saving model to training\cp-0015.ckpt
# 244/804 [========>.....................] - ETA: 0s - loss: 0.5429 - accuracy: 0.7363
# Epoch 00015: saving model to training\cp-0015.ckpt
# 400/804 [=============>................] - ETA: 0s - loss: 0.5438 - accuracy: 0.7345
# Epoch 00015: saving model to training\cp-0015.ckpt
# 579/804 [====================>.........] - ETA: 0s - loss: 0.5446 - accuracy: 0.7335
# Epoch 00015: saving model to training\cp-0015.ckpt
# 743/804 [==========================>...] - ETA: 0s - loss: 0.5447 - accuracy: 0.7333
# Epoch 00015: saving model to training\cp-0015.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5453 - accuracy: 0.7331 - val_loss: 0.6943 - val_accuracy: 0.4746
# Epoch 16/50
#  92/804 [==>...........................] - ETA: 1s - loss: 0.5464 - accuracy: 0.7313
# Epoch 00016: saving model to training\cp-0016.ckpt
# 252/804 [========>.....................] - ETA: 1s - loss: 0.5457 - accuracy: 0.7367
# Epoch 00016: saving model to training\cp-0016.ckpt
# 414/804 [==============>...............] - ETA: 0s - loss: 0.5444 - accuracy: 0.7339
# Epoch 00016: saving model to training\cp-0016.ckpt
# 576/804 [====================>.........] - ETA: 0s - loss: 0.5467 - accuracy: 0.7324
# Epoch 00016: saving model to training\cp-0016.ckpt
# 710/804 [=========================>....] - ETA: 0s - loss: 0.5451 - accuracy: 0.7329
# Epoch 00016: saving model to training\cp-0016.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5451 - accuracy: 0.7335 - val_loss: 0.6944 - val_accuracy: 0.4746
# Epoch 17/50
#  93/804 [==>...........................] - ETA: 1s - loss: 0.5445 - accuracy: 0.7224
# Epoch 00017: saving model to training\cp-0017.ckpt
# 255/804 [========>.....................] - ETA: 0s - loss: 0.5475 - accuracy: 0.7295
# Epoch 00017: saving model to training\cp-0017.ckpt
# 390/804 [=============>................] - ETA: 0s - loss: 0.5501 - accuracy: 0.7276
# Epoch 00017: saving model to training\cp-0017.ckpt
# 564/804 [====================>.........] - ETA: 0s - loss: 0.5467 - accuracy: 0.7311
# Epoch 00017: saving model to training\cp-0017.ckpt
# 729/804 [==========================>...] - ETA: 0s - loss: 0.5454 - accuracy: 0.7317
# Epoch 00017: saving model to training\cp-0017.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5445 - accuracy: 0.7329 - val_loss: 0.7393 - val_accuracy: 0.4746
# Epoch 18/50
#  62/804 [=>............................] - ETA: 1s - loss: 0.5456 - accuracy: 0.7253
# Epoch 00018: saving model to training\cp-0018.ckpt
# 243/804 [========>.....................] - ETA: 1s - loss: 0.5427 - accuracy: 0.7334
# Epoch 00018: saving model to training\cp-0018.ckpt
# 401/804 [=============>................] - ETA: 0s - loss: 0.5429 - accuracy: 0.7327
# Epoch 00018: saving model to training\cp-0018.ckpt
# 565/804 [====================>.........] - ETA: 0s - loss: 0.5450 - accuracy: 0.7320
# Epoch 00018: saving model to training\cp-0018.ckpt
# 727/804 [==========================>...] - ETA: 0s - loss: 0.5429 - accuracy: 0.7338
# Epoch 00018: saving model to training\cp-0018.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5441 - accuracy: 0.7332 - val_loss: 0.7183 - val_accuracy: 0.4746
# Epoch 19/50
#  60/804 [=>............................] - ETA: 1s - loss: 0.5371 - accuracy: 0.7505
# Epoch 00019: saving model to training\cp-0019.ckpt
# 223/804 [=======>......................] - ETA: 1s - loss: 0.5441 - accuracy: 0.7358
# Epoch 00019: saving model to training\cp-0019.ckpt
# 398/804 [=============>................] - ETA: 0s - loss: 0.5442 - accuracy: 0.7356
# Epoch 00019: saving model to training\cp-0019.ckpt
# 561/804 [===================>..........] - ETA: 0s - loss: 0.5436 - accuracy: 0.7370
# Epoch 00019: saving model to training\cp-0019.ckpt
# 722/804 [=========================>....] - ETA: 0s - loss: 0.5431 - accuracy: 0.7352
# Epoch 00019: saving model to training\cp-0019.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5442 - accuracy: 0.7338 - val_loss: 0.7263 - val_accuracy: 0.4746
# Epoch 20/50
#  60/804 [=>............................] - ETA: 1s - loss: 0.5320 - accuracy: 0.7474
# Epoch 00020: saving model to training\cp-0020.ckpt
# 233/804 [=======>......................] - ETA: 1s - loss: 0.5445 - accuracy: 0.7356
# Epoch 00020: saving model to training\cp-0020.ckpt
# 400/804 [=============>................] - ETA: 0s - loss: 0.5428 - accuracy: 0.7326
# Epoch 00020: saving model to training\cp-0020.ckpt
# 561/804 [===================>..........] - ETA: 0s - loss: 0.5430 - accuracy: 0.7320
# Epoch 00020: saving model to training\cp-0020.ckpt
# 720/804 [=========================>....] - ETA: 0s - loss: 0.5447 - accuracy: 0.7306
# Epoch 00020: saving model to training\cp-0020.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5435 - accuracy: 0.7322 - val_loss: 0.7150 - val_accuracy: 0.4746
# Epoch 21/50
#  62/804 [=>............................] - ETA: 1s - loss: 0.5229 - accuracy: 0.7560
# Epoch 00021: saving model to training\cp-0021.ckpt
# 230/804 [=======>......................] - ETA: 1s - loss: 0.5352 - accuracy: 0.7448
# Epoch 00021: saving model to training\cp-0021.ckpt
# 389/804 [=============>................] - ETA: 0s - loss: 0.5394 - accuracy: 0.7394
# Epoch 00021: saving model to training\cp-0021.ckpt
# 554/804 [===================>..........] - ETA: 0s - loss: 0.5420 - accuracy: 0.7366
# Epoch 00021: saving model to training\cp-0021.ckpt
# 712/804 [=========================>....] - ETA: 0s - loss: 0.5437 - accuracy: 0.7350
# Epoch 00021: saving model to training\cp-0021.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5433 - accuracy: 0.7348 - val_loss: 0.6927 - val_accuracy: 0.5254
# Epoch 22/50
#  61/804 [=>............................] - ETA: 1s - loss: 0.5381 - accuracy: 0.7398
# Epoch 00022: saving model to training\cp-0022.ckpt
# 224/804 [=======>......................] - ETA: 1s - loss: 0.5417 - accuracy: 0.7341
# Epoch 00022: saving model to training\cp-0022.ckpt
# 385/804 [=============>................] - ETA: 0s - loss: 0.5390 - accuracy: 0.7362
# Epoch 00022: saving model to training\cp-0022.ckpt
# 543/804 [===================>..........] - ETA: 0s - loss: 0.5403 - accuracy: 0.7346
# Epoch 00022: saving model to training\cp-0022.ckpt
# 704/804 [=========================>....] - ETA: 0s - loss: 0.5425 - accuracy: 0.7342
# Epoch 00022: saving model to training\cp-0022.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5433 - accuracy: 0.7336 - val_loss: 0.7915 - val_accuracy: 0.4746
# Epoch 23/50
#  61/804 [=>............................] - ETA: 1s - loss: 0.5204 - accuracy: 0.7510
# Epoch 00023: saving model to training\cp-0023.ckpt
# 222/804 [=======>......................] - ETA: 1s - loss: 0.5430 - accuracy: 0.7323
# Epoch 00023: saving model to training\cp-0023.ckpt
# 382/804 [=============>................] - ETA: 0s - loss: 0.5411 - accuracy: 0.7355
# Epoch 00023: saving model to training\cp-0023.ckpt
# 539/804 [===================>..........] - ETA: 0s - loss: 0.5439 - accuracy: 0.7334
# Epoch 00023: saving model to training\cp-0023.ckpt
# 708/804 [=========================>....] - ETA: 0s - loss: 0.5447 - accuracy: 0.7337
# Epoch 00023: saving model to training\cp-0023.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5434 - accuracy: 0.7343 - val_loss: 0.7100 - val_accuracy: 0.4746
# Epoch 24/50
#  62/804 [=>............................] - ETA: 1s - loss: 0.5396 - accuracy: 0.7319
# Epoch 00024: saving model to training\cp-0024.ckpt
# 219/804 [=======>......................] - ETA: 1s - loss: 0.5452 - accuracy: 0.7320
# Epoch 00024: saving model to training\cp-0024.ckpt
# 378/804 [=============>................] - ETA: 0s - loss: 0.5427 - accuracy: 0.7347
# Epoch 00024: saving model to training\cp-0024.ckpt
# 539/804 [===================>..........] - ETA: 0s - loss: 0.5439 - accuracy: 0.7346
# Epoch 00024: saving model to training\cp-0024.ckpt
# 700/804 [=========================>....] - ETA: 0s - loss: 0.5444 - accuracy: 0.7339
# Epoch 00024: saving model to training\cp-0024.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5429 - accuracy: 0.7344 - val_loss: 0.6922 - val_accuracy: 0.5254
# Epoch 25/50
#  60/804 [=>............................] - ETA: 1s - loss: 0.5498 - accuracy: 0.7188
# Epoch 00025: saving model to training\cp-0025.ckpt
# 196/804 [======>.......................] - ETA: 1s - loss: 0.5474 - accuracy: 0.7291
# Epoch 00025: saving model to training\cp-0025.ckpt
# 375/804 [============>.................] - ETA: 0s - loss: 0.5471 - accuracy: 0.7288
# Epoch 00025: saving model to training\cp-0025.ckpt
# 536/804 [===================>..........] - ETA: 0s - loss: 0.5467 - accuracy: 0.7294
# Epoch 00025: saving model to training\cp-0025.ckpt
# 697/804 [=========================>....] - ETA: 0s - loss: 0.5436 - accuracy: 0.7331
# Epoch 00025: saving model to training\cp-0025.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5428 - accuracy: 0.7334 - val_loss: 0.7131 - val_accuracy: 0.4746
# Epoch 26/50
#  31/804 [>.............................] - ETA: 1s - loss: 0.5302 - accuracy: 0.7510
# Epoch 00026: saving model to training\cp-0026.ckpt
# 215/804 [=======>......................] - ETA: 1s - loss: 0.5408 - accuracy: 0.7385
# Epoch 00026: saving model to training\cp-0026.ckpt
# 376/804 [=============>................] - ETA: 0s - loss: 0.5426 - accuracy: 0.7362
# Epoch 00026: saving model to training\cp-0026.ckpt
# 534/804 [==================>...........] - ETA: 0s - loss: 0.5408 - accuracy: 0.7370
# Epoch 00026: saving model to training\cp-0026.ckpt
# 694/804 [========================>.....] - ETA: 0s - loss: 0.5422 - accuracy: 0.7347
# Epoch 00026: saving model to training\cp-0026.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5424 - accuracy: 0.7344 - val_loss: 0.6923 - val_accuracy: 0.5254
# Epoch 27/50
#  33/804 [>.............................] - ETA: 1s - loss: 0.5334 - accuracy: 0.7216
# Epoch 00027: saving model to training\cp-0027.ckpt
# 208/804 [======>.......................] - ETA: 1s - loss: 0.5413 - accuracy: 0.7323
# Epoch 00027: saving model to training\cp-0027.ckpt
# 370/804 [============>.................] - ETA: 0s - loss: 0.5434 - accuracy: 0.7295
# Epoch 00027: saving model to training\cp-0027.ckpt
# 509/804 [=================>............] - ETA: 0s - loss: 0.5406 - accuracy: 0.7326
# Epoch 00027: saving model to training\cp-0027.ckpt
# 690/804 [========================>.....] - ETA: 0s - loss: 0.5408 - accuracy: 0.7334
# Epoch 00027: saving model to training\cp-0027.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5419 - accuracy: 0.7334 - val_loss: 0.6919 - val_accuracy: 0.5254
# Epoch 28/50
#  34/804 [>.............................] - ETA: 1s - loss: 0.5619 - accuracy: 0.7086
# Epoch 00028: saving model to training\cp-0028.ckpt
# 204/804 [======>.......................] - ETA: 1s - loss: 0.5389 - accuracy: 0.7361
# Epoch 00028: saving model to training\cp-0028.ckpt
# 371/804 [============>.................] - ETA: 0s - loss: 0.5452 - accuracy: 0.7300
# Epoch 00028: saving model to training\cp-0028.ckpt
# 504/804 [=================>............] - ETA: 0s - loss: 0.5450 - accuracy: 0.7289
# Epoch 00028: saving model to training\cp-0028.ckpt
# 682/804 [========================>.....] - ETA: 0s - loss: 0.5420 - accuracy: 0.7330
# Epoch 00028: saving model to training\cp-0028.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5417 - accuracy: 0.7333 - val_loss: 0.7040 - val_accuracy: 0.4746
# Epoch 29/50
#  39/804 [>.............................] - ETA: 1s - loss: 0.5313 - accuracy: 0.7484
# Epoch 00029: saving model to training\cp-0029.ckpt
# 207/804 [======>.......................] - ETA: 1s - loss: 0.5370 - accuracy: 0.7378
# Epoch 00029: saving model to training\cp-0029.ckpt
# 360/804 [============>.................] - ETA: 0s - loss: 0.5373 - accuracy: 0.7385
# Epoch 00029: saving model to training\cp-0029.ckpt
# 521/804 [==================>...........] - ETA: 0s - loss: 0.5395 - accuracy: 0.7366
# Epoch 00029: saving model to training\cp-0029.ckpt
# 682/804 [========================>.....] - ETA: 0s - loss: 0.5413 - accuracy: 0.7340
# Epoch 00029: saving model to training\cp-0029.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5417 - accuracy: 0.7341 - val_loss: 0.7404 - val_accuracy: 0.4746
# Epoch 30/50
#  32/804 [>.............................] - ETA: 1s - loss: 0.5397 - accuracy: 0.7402
# Epoch 00030: saving model to training\cp-0030.ckpt
# 195/804 [======>.......................] - ETA: 1s - loss: 0.5434 - accuracy: 0.7309
# Epoch 00030: saving model to training\cp-0030.ckpt
# 362/804 [============>.................] - ETA: 0s - loss: 0.5400 - accuracy: 0.7326
# Epoch 00030: saving model to training\cp-0030.ckpt
# 494/804 [=================>............] - ETA: 0s - loss: 0.5406 - accuracy: 0.7336
# Epoch 00030: saving model to training\cp-0030.ckpt
# 673/804 [========================>.....] - ETA: 0s - loss: 0.5419 - accuracy: 0.7337
# Epoch 00030: saving model to training\cp-0030.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5413 - accuracy: 0.7344 - val_loss: 0.7176 - val_accuracy: 0.4746
# Epoch 31/50
#  31/804 [>.............................] - ETA: 1s - loss: 0.5426 - accuracy: 0.7419
# Epoch 00031: saving model to training\cp-0031.ckpt
# 194/804 [======>.......................] - ETA: 1s - loss: 0.5438 - accuracy: 0.7316
# Epoch 00031: saving model to training\cp-0031.ckpt
# 354/804 [============>.................] - ETA: 0s - loss: 0.5429 - accuracy: 0.7335
# Epoch 00031: saving model to training\cp-0031.ckpt
# 514/804 [==================>...........] - ETA: 0s - loss: 0.5425 - accuracy: 0.7323
# Epoch 00031: saving model to training\cp-0031.ckpt
# 676/804 [========================>.....] - ETA: 0s - loss: 0.5408 - accuracy: 0.7348
# Epoch 00031: saving model to training\cp-0031.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5408 - accuracy: 0.7360 - val_loss: 0.6920 - val_accuracy: 0.5254
# Epoch 32/50
#  31/804 [>.............................] - ETA: 1s - loss: 0.5101 - accuracy: 0.7581
# Epoch 00032: saving model to training\cp-0032.ckpt
# 195/804 [======>.......................] - ETA: 1s - loss: 0.5411 - accuracy: 0.7377
# Epoch 00032: saving model to training\cp-0032.ckpt
# 341/804 [===========>..................] - ETA: 0s - loss: 0.5472 - accuracy: 0.7307
# Epoch 00032: saving model to training\cp-0032.ckpt
# 505/804 [=================>............] - ETA: 0s - loss: 0.5437 - accuracy: 0.7345
# Epoch 00032: saving model to training\cp-0032.ckpt
# 664/804 [=======================>......] - ETA: 0s - loss: 0.5412 - accuracy: 0.7361
# Epoch 00032: saving model to training\cp-0032.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5410 - accuracy: 0.7361 - val_loss: 0.7267 - val_accuracy: 0.4746
# Epoch 33/50
#  31/804 [>.............................] - ETA: 1s - loss: 0.5493 - accuracy: 0.7298
# Epoch 00033: saving model to training\cp-0033.ckpt
# 190/804 [======>.......................] - ETA: 1s - loss: 0.5436 - accuracy: 0.7293
# Epoch 00033: saving model to training\cp-0033.ckpt
# 350/804 [============>.................] - ETA: 0s - loss: 0.5429 - accuracy: 0.7311
# Epoch 00033: saving model to training\cp-0033.ckpt
# 511/804 [==================>...........] - ETA: 0s - loss: 0.5437 - accuracy: 0.7312
# Epoch 00033: saving model to training\cp-0033.ckpt
# 644/804 [=======================>......] - ETA: 0s - loss: 0.5434 - accuracy: 0.7326
# Epoch 00033: saving model to training\cp-0033.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5410 - accuracy: 0.7354 - val_loss: 0.7205 - val_accuracy: 0.4746
# Epoch 34/50
#   1/804 [..............................] - ETA: 2s - loss: 0.5477 - accuracy: 0.7188
# Epoch 00034: saving model to training\cp-0034.ckpt
# 187/804 [=====>........................] - ETA: 1s - loss: 0.5363 - accuracy: 0.7381
# Epoch 00034: saving model to training\cp-0034.ckpt
# 323/804 [===========>..................] - ETA: 0s - loss: 0.5387 - accuracy: 0.7385
# Epoch 00034: saving model to training\cp-0034.ckpt
# 496/804 [=================>............] - ETA: 0s - loss: 0.5384 - accuracy: 0.7373
# Epoch 00034: saving model to training\cp-0034.ckpt
# 658/804 [=======================>......] - ETA: 0s - loss: 0.5420 - accuracy: 0.7339
# Epoch 00034: saving model to training\cp-0034.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5409 - accuracy: 0.7351 - val_loss: 0.7260 - val_accuracy: 0.4746
# Epoch 35/50
#   1/804 [..............................] - ETA: 2s - loss: 0.5069 - accuracy: 0.7812
# Epoch 00035: saving model to training\cp-0035.ckpt
# 171/804 [=====>........................] - ETA: 1s - loss: 0.5374 - accuracy: 0.7374
# Epoch 00035: saving model to training\cp-0035.ckpt
# 332/804 [===========>..................] - ETA: 0s - loss: 0.5359 - accuracy: 0.7380
# Epoch 00035: saving model to training\cp-0035.ckpt
# 493/804 [=================>............] - ETA: 0s - loss: 0.5370 - accuracy: 0.7399
# Epoch 00035: saving model to training\cp-0035.ckpt
# 654/804 [=======================>......] - ETA: 0s - loss: 0.5391 - accuracy: 0.7375
# Epoch 00035: saving model to training\cp-0035.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5406 - accuracy: 0.7362 - val_loss: 0.7533 - val_accuracy: 0.4746
# Epoch 36/50
#   1/804 [..............................] - ETA: 1s - loss: 0.5086 - accuracy: 0.7500
# Epoch 00036: saving model to training\cp-0036.ckpt
# 168/804 [=====>........................] - ETA: 1s - loss: 0.5358 - accuracy: 0.7398
# Epoch 00036: saving model to training\cp-0036.ckpt
# 332/804 [===========>..................] - ETA: 0s - loss: 0.5363 - accuracy: 0.7404
# Epoch 00036: saving model to training\cp-0036.ckpt
# 470/804 [================>.............] - ETA: 0s - loss: 0.5349 - accuracy: 0.7402
# Epoch 00036: saving model to training\cp-0036.ckpt
# 651/804 [=======================>......] - ETA: 0s - loss: 0.5378 - accuracy: 0.7377
# Epoch 00036: saving model to training\cp-0036.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5401 - accuracy: 0.7357 - val_loss: 0.6925 - val_accuracy: 0.5254
# Epoch 37/50
#   1/804 [..............................] - ETA: 1s - loss: 0.6444 - accuracy: 0.6562
# Epoch 00037: saving model to training\cp-0037.ckpt
# 168/804 [=====>........................] - ETA: 1s - loss: 0.5362 - accuracy: 0.7366
# Epoch 00037: saving model to training\cp-0037.ckpt
# 324/804 [===========>..................] - ETA: 0s - loss: 0.5432 - accuracy: 0.7328
# Epoch 00037: saving model to training\cp-0037.ckpt
# 482/804 [================>.............] - ETA: 0s - loss: 0.5396 - accuracy: 0.7341
# Epoch 00037: saving model to training\cp-0037.ckpt
# 652/804 [=======================>......] - ETA: 0s - loss: 0.5388 - accuracy: 0.7360
# Epoch 00037: saving model to training\cp-0037.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5401 - accuracy: 0.7352 - val_loss: 0.7900 - val_accuracy: 0.4746
# Epoch 38/50
#   1/804 [..............................] - ETA: 2s - loss: 0.5921 - accuracy: 0.6562
# Epoch 00038: saving model to training\cp-0038.ckpt
# 165/804 [=====>........................] - ETA: 1s - loss: 0.5394 - accuracy: 0.7400
# Epoch 00038: saving model to training\cp-0038.ckpt
# 323/804 [===========>..................] - ETA: 0s - loss: 0.5361 - accuracy: 0.7399
# Epoch 00038: saving model to training\cp-0038.ckpt
# 483/804 [=================>............] - ETA: 0s - loss: 0.5371 - accuracy: 0.7387
# Epoch 00038: saving model to training\cp-0038.ckpt
# 643/804 [======================>.......] - ETA: 0s - loss: 0.5381 - accuracy: 0.7381
# Epoch 00038: saving model to training\cp-0038.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5404 - accuracy: 0.7367 - val_loss: 0.9602 - val_accuracy: 0.4746
# Epoch 39/50
#   1/804 [..............................] - ETA: 1s - loss: 0.4338 - accuracy: 0.8125
# Epoch 00039: saving model to training\cp-0039.ckpt
# 164/804 [=====>........................] - ETA: 1s - loss: 0.5350 - accuracy: 0.7384
# Epoch 00039: saving model to training\cp-0039.ckpt
# 324/804 [===========>..................] - ETA: 0s - loss: 0.5367 - accuracy: 0.7372
# Epoch 00039: saving model to training\cp-0039.ckpt
# 487/804 [=================>............] - ETA: 0s - loss: 0.5387 - accuracy: 0.7359
# Epoch 00039: saving model to training\cp-0039.ckpt
# 647/804 [=======================>......] - ETA: 0s - loss: 0.5400 - accuracy: 0.7359
# Epoch 00039: saving model to training\cp-0039.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5398 - accuracy: 0.7360 - val_loss: 0.9421 - val_accuracy: 0.4746
# Epoch 40/50
#   1/804 [..............................] - ETA: 1s - loss: 0.5631 - accuracy: 0.7188
# Epoch 00040: saving model to training\cp-0040.ckpt
# 160/804 [====>.........................] - ETA: 1s - loss: 0.5464 - accuracy: 0.7316
# Epoch 00040: saving model to training\cp-0040.ckpt
# 315/804 [==========>...................] - ETA: 0s - loss: 0.5390 - accuracy: 0.7348
# Epoch 00040: saving model to training\cp-0040.ckpt
# 475/804 [================>.............] - ETA: 0s - loss: 0.5422 - accuracy: 0.7317
# Epoch 00040: saving model to training\cp-0040.ckpt
# 635/804 [======================>.......] - ETA: 0s - loss: 0.5413 - accuracy: 0.7339
# Epoch 00040: saving model to training\cp-0040.ckpt
# 794/804 [============================>.] - ETA: 0s - loss: 0.5399 - accuracy: 0.7350
# Epoch 00040: saving model to training\cp-0040.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5398 - accuracy: 0.7349 - val_loss: 0.9668 - val_accuracy: 0.4746
# Epoch 41/50
# 153/804 [====>.........................] - ETA: 1s - loss: 0.5342 - accuracy: 0.7390
# Epoch 00041: saving model to training\cp-0041.ckpt
# 315/804 [==========>...................] - ETA: 0s - loss: 0.5348 - accuracy: 0.7382
# Epoch 00041: saving model to training\cp-0041.ckpt
# 476/804 [================>.............] - ETA: 0s - loss: 0.5373 - accuracy: 0.7366
# Epoch 00041: saving model to training\cp-0041.ckpt
# 613/804 [=====================>........] - ETA: 0s - loss: 0.5405 - accuracy: 0.7345
# Epoch 00041: saving model to training\cp-0041.ckpt
# 797/804 [============================>.] - ETA: 0s - loss: 0.5398 - accuracy: 0.7359
# Epoch 00041: saving model to training\cp-0041.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5398 - accuracy: 0.7360 - val_loss: 0.8320 - val_accuracy: 0.4746
# Epoch 42/50
# 152/804 [====>.........................] - ETA: 1s - loss: 0.5389 - accuracy: 0.7430
# Epoch 00042: saving model to training\cp-0042.ckpt
# 314/804 [==========>...................] - ETA: 0s - loss: 0.5333 - accuracy: 0.7427
# Epoch 00042: saving model to training\cp-0042.ckpt
# 450/804 [===============>..............] - ETA: 0s - loss: 0.5367 - accuracy: 0.7390
# Epoch 00042: saving model to training\cp-0042.ckpt
# 617/804 [======================>.......] - ETA: 0s - loss: 0.5411 - accuracy: 0.7360
# Epoch 00042: saving model to training\cp-0042.ckpt
# 770/804 [===========================>..] - ETA: 0s - loss: 0.5397 - accuracy: 0.7373
# Epoch 00042: saving model to training\cp-0042.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5391 - accuracy: 0.7375 - val_loss: 0.7668 - val_accuracy: 0.4746
# Epoch 43/50
# 125/804 [===>..........................] - ETA: 1s - loss: 0.5459 - accuracy: 0.7327
# Epoch 00043: saving model to training\cp-0043.ckpt
# 302/804 [==========>...................] - ETA: 0s - loss: 0.5370 - accuracy: 0.7388
# Epoch 00043: saving model to training\cp-0043.ckpt
# 471/804 [================>.............] - ETA: 0s - loss: 0.5392 - accuracy: 0.7355
# Epoch 00043: saving model to training\cp-0043.ckpt
# 609/804 [=====================>........] - ETA: 0s - loss: 0.5394 - accuracy: 0.7350
# Epoch 00043: saving model to training\cp-0043.ckpt
# 787/804 [============================>.] - ETA: 0s - loss: 0.5400 - accuracy: 0.7353
# Epoch 00043: saving model to training\cp-0043.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5395 - accuracy: 0.7357 - val_loss: 0.7175 - val_accuracy: 0.4746
# Epoch 44/50
# 136/804 [====>.........................] - ETA: 1s - loss: 0.5317 - accuracy: 0.7410
# Epoch 00044: saving model to training\cp-0044.ckpt
# 280/804 [=========>....................] - ETA: 0s - loss: 0.5339 - accuracy: 0.7422
# Epoch 00044: saving model to training\cp-0044.ckpt
# 442/804 [===============>..............] - ETA: 0s - loss: 0.5358 - accuracy: 0.7405
# Epoch 00044: saving model to training\cp-0044.ckpt
# 623/804 [======================>.......] - ETA: 0s - loss: 0.5380 - accuracy: 0.7365
# Epoch 00044: saving model to training\cp-0044.ckpt
# 761/804 [===========================>..] - ETA: 0s - loss: 0.5390 - accuracy: 0.7362
# Epoch 00044: saving model to training\cp-0044.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5391 - accuracy: 0.7358 - val_loss: 0.6919 - val_accuracy: 0.5254
# Epoch 45/50
# 124/804 [===>..........................] - ETA: 1s - loss: 0.5501 - accuracy: 0.7263
# Epoch 00045: saving model to training\cp-0045.ckpt
# 276/804 [=========>....................] - ETA: 0s - loss: 0.5378 - accuracy: 0.7386
# Epoch 00045: saving model to training\cp-0045.ckpt
# 433/804 [===============>..............] - ETA: 0s - loss: 0.5384 - accuracy: 0.7380
# Epoch 00045: saving model to training\cp-0045.ckpt
# 616/804 [=====================>........] - ETA: 0s - loss: 0.5360 - accuracy: 0.7407
# Epoch 00045: saving model to training\cp-0045.ckpt
# 783/804 [============================>.] - ETA: 0s - loss: 0.5395 - accuracy: 0.7366
# Epoch 00045: saving model to training\cp-0045.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5392 - accuracy: 0.7367 - val_loss: 0.6921 - val_accuracy: 0.5254
# Epoch 46/50
# 128/804 [===>..........................] - ETA: 1s - loss: 0.5313 - accuracy: 0.7400
# Epoch 00046: saving model to training\cp-0046.ckpt
# 268/804 [=========>....................] - ETA: 0s - loss: 0.5371 - accuracy: 0.7359
# Epoch 00046: saving model to training\cp-0046.ckpt
# 455/804 [===============>..............] - ETA: 0s - loss: 0.5392 - accuracy: 0.7362
# Epoch 00046: saving model to training\cp-0046.ckpt
# 593/804 [=====================>........] - ETA: 0s - loss: 0.5406 - accuracy: 0.7356
# Epoch 00046: saving model to training\cp-0046.ckpt
# 749/804 [==========================>...] - ETA: 0s - loss: 0.5388 - accuracy: 0.7370
# Epoch 00046: saving model to training\cp-0046.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5391 - accuracy: 0.7367 - val_loss: 0.6943 - val_accuracy: 0.5254
# Epoch 47/50
# 123/804 [===>..........................] - ETA: 1s - loss: 0.5429 - accuracy: 0.7376
# Epoch 00047: saving model to training\cp-0047.ckpt
# 263/804 [========>.....................] - ETA: 0s - loss: 0.5416 - accuracy: 0.7361
# Epoch 00047: saving model to training\cp-0047.ckpt
# 455/804 [===============>..............] - ETA: 0s - loss: 0.5377 - accuracy: 0.7367
# Epoch 00047: saving model to training\cp-0047.ckpt
# 595/804 [=====================>........] - ETA: 0s - loss: 0.5393 - accuracy: 0.7356
# Epoch 00047: saving model to training\cp-0047.ckpt
# 744/804 [==========================>...] - ETA: 0s - loss: 0.5402 - accuracy: 0.7357
# Epoch 00047: saving model to training\cp-0047.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5389 - accuracy: 0.7368 - val_loss: 0.7093 - val_accuracy: 0.4746
# Epoch 48/50
# 130/804 [===>..........................] - ETA: 1s - loss: 0.5348 - accuracy: 0.7387
# Epoch 00048: saving model to training\cp-0048.ckpt
# 268/804 [=========>....................] - ETA: 0s - loss: 0.5337 - accuracy: 0.7376
# Epoch 00048: saving model to training\cp-0048.ckpt
# 421/804 [==============>...............] - ETA: 0s - loss: 0.5352 - accuracy: 0.7381
# Epoch 00048: saving model to training\cp-0048.ckpt
# 608/804 [=====================>........] - ETA: 0s - loss: 0.5363 - accuracy: 0.7387
# Epoch 00048: saving model to training\cp-0048.ckpt
# 748/804 [==========================>...] - ETA: 0s - loss: 0.5376 - accuracy: 0.7383
# Epoch 00048: saving model to training\cp-0048.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5387 - accuracy: 0.7369 - val_loss: 0.7118 - val_accuracy: 0.4746
# Epoch 49/50
#  97/804 [==>...........................] - ETA: 1s - loss: 0.5261 - accuracy: 0.7506
# Epoch 00049: saving model to training\cp-0049.ckpt
# 259/804 [========>.....................] - ETA: 0s - loss: 0.5375 - accuracy: 0.7388
# Epoch 00049: saving model to training\cp-0049.ckpt
# 447/804 [===============>..............] - ETA: 0s - loss: 0.5374 - accuracy: 0.7384
# Epoch 00049: saving model to training\cp-0049.ckpt
# 582/804 [====================>.........] - ETA: 0s - loss: 0.5376 - accuracy: 0.7389
# Epoch 00049: saving model to training\cp-0049.ckpt
# 743/804 [==========================>...] - ETA: 0s - loss: 0.5361 - accuracy: 0.7399
# Epoch 00049: saving model to training\cp-0049.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5387 - accuracy: 0.7381 - val_loss: 0.7349 - val_accuracy: 0.4746
# Epoch 50/50
#  94/804 [==>...........................] - ETA: 1s - loss: 0.5386 - accuracy: 0.7317
# Epoch 00050: saving model to training\cp-0050.ckpt
# 282/804 [=========>....................] - ETA: 0s - loss: 0.5428 - accuracy: 0.7329
# Epoch 00050: saving model to training\cp-0050.ckpt
# 419/804 [==============>...............] - ETA: 0s - loss: 0.5383 - accuracy: 0.7378
# Epoch 00050: saving model to training\cp-0050.ckpt
# 603/804 [=====================>........] - ETA: 0s - loss: 0.5386 - accuracy: 0.7380
# Epoch 00050: saving model to training\cp-0050.ckpt
# 736/804 [==========================>...] - ETA: 0s - loss: 0.5380 - accuracy: 0.7381
# Epoch 00050: saving model to training\cp-0050.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5385 - accuracy: 0.7375 - val_loss: 0.8024 - val_accuracy: 0.4746

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5484 - accuracy: 0.7346 - 611ms/epoch - 2ms/step
# Loss: 0.548416256904602, Accuracy: 0.7345772385597229

# %%
# Export our model to HDF5 file

nn_model.save('../HDF5_Files/AlphabetSoupCharity.h5')

# %%
history_df = pd.DataFrame(fit_model.history)

history_df.index += 1

history_df.plot(y='loss', color = 'red')
plt.xlabel('Epoch Index')
plt.ylabel('Loss')
plt.title('Training Loss Graph')
plt.legend (loc = 'center right')
plt.savefig("../Images/Model_Loss.png")


history_df.plot(y='accuracy', color = 'green')
plt.xlabel('Epoch Index')
plt.ylabel('Accuracy')
plt.title('Training Accuracy Graph')
plt.legend (loc = 'center right')
plt.savefig("../Images/Model_Accuracy.png")


plt.figure(figsize = (15,5))
plt.plot(history_df['loss'], color='red', label='loss', )
plt.plot(history_df['accuracy'], color='green', label='accuracy')
plt.xlim([0, 52])
plt.ylim([0.45, 0.8])
plt.xlabel('Epoch Index')
plt.ylabel('Accuracy/Loss')
plt.title('Model Training Accuracy/Loss Graph')
plt.legend(loc = 'center right')
plt.savefig("../Images/ModelAccuracy_Loss.png")
plt.show()
