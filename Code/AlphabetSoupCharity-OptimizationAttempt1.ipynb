# %% [markdown]
# # Charity Funding Predictor - Optimization Attempt 1

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
# tf.keras.callbacks.ModelCheckpoint

#  read the charity_data.csv.
application_df = pd.read_csv("../Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
pd.options.display.max_columns = 50

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
df = application_df.drop(columns = ['EIN', 'NAME'])
df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = df['APPLICATION_TYPE'].value_counts() \
                                                        .loc[lambda x : x < 200] \
                                                        .index \
                                                        .to_list()
application_types_to_replace
# Out:
# ['T9', 'T13', 'T12', 'T2', 'T25', 'T14', 'T29', 'T15', 'T17']

# %%
# Replace in dataframe
for app in application_types_to_replace:
    df['APPLICATION_TYPE'] = df['APPLICATION_TYPE'].replace(app,"Other")

# %%
# Check to make sure binning was successful
df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
df['CLASSIFICATION'].value_counts().loc[lambda x: x>1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = df['CLASSIFICATION'].value_counts() \
                                                    .loc[lambda x : x < 1000] \
                                                    .index \
                                                    .to_list()
# Replace in dataframe
for cls in classifications_to_replace:
    df['CLASSIFICATION'] = df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
df.nunique()
# Out:
# APPLICATION_TYPE             9
# AFFILIATION                  6
# CLASSIFICATION               6
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
transformed_df = pd.get_dummies(df)
transformed_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# 1                         0                     0                    1
# 2                         0                     0                    0
# 3                         0                     0                    1
# 4                         0                     0                    1
# ...                     ...                   ...                  ...
# 34294                     0                     0                    0
# 34295                     0                     0                    0
# 34296                     0                     0                    1
# 34297                     0                     0                    0
# 34298                     0                     0                    1
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  \
# 0                        0                    0                    0
# 1                        0                    0                    0
# 2                        0                    1                    0
# 3                        0                    0                    0
# 4                        0                    0                    0
# ...                    ...                  ...                  ...
# 34294                    1                    0                    0
# 34295                    1                    0                    0
# 34296                    0                    0                    0
# 34297                    0                    1                    0
# 34298                    0                    0                    0
#
#        APPLICATION_TYPE_T7  APPLICATION_TYPE_T8  AFFILIATION_CompanySponsored  \
# 0                        0                    0                             0
# 1                        0                    0                             0
# 2                        0                    0                             1
# 3                        0                    0                             1
# 4                        0                    0                             0
# ...                    ...                  ...                           ...
# 34294                    0                    0                             0
# 34295                    0                    0                             1
# 34296                    0                    0                             1
# 34297                    0                    0                             0
# 34298                    0                    0                             0
#
#        AFFILIATION_Family/Parent  AFFILIATION_Independent  \
# 0                              0                        1
# 1                              0                        1
# 2                              0                        0
# 3                              0                        0
# 4                              0                        1
# ...                          ...                      ...
# 34294                          0                        1
# 34295                          0                        0
# 34296                          0                        0
# 34297                          0                        1
# 34298                          0                        1
#
#        AFFILIATION_National  AFFILIATION_Other  AFFILIATION_Regional  \
# 0                         0                  0                     0
# 1                         0                  0                     0
# 2                         0                  0                     0
# 3                         0                  0                     0
# 4                         0                  0                     0
# ...                     ...                ...                   ...
# 34294                     0                  0                     0
# 34295                     0                  0                     0
# 34296                     0                  0                     0
# 34297                     0                  0                     0
# 34298                     0                  0                     0
#
#        CLASSIFICATION_C1000  CLASSIFICATION_C1200  CLASSIFICATION_C2000  \
# 0                         1                     0                     0
# 1                         0                     0                     1
# 2                         0                     0                     0
# 3                         0                     0                     1
# 4                         1                     0                     0
# ...                     ...                   ...                   ...
# 34294                     1                     0                     0
# 34295                     0                     0                     0
# 34296                     0                     0                     1
# 34297                     0                     0                     0
# 34298                     1                     0                     0
#
#        CLASSIFICATION_C2100  CLASSIFICATION_C3000  CLASSIFICATION_Other  \
# 0                         0                     0                     0
# 1                         0                     0                     0
# 2                         0                     1                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# ...                     ...                   ...                   ...
# 34294                     0                     0                     0
# 34295                     0                     1                     0
# 34296                     0                     0                     0
# 34297                     0                     1                     0
# 34298                     0                     0                     0
#
#        USE_CASE_CommunityServ  USE_CASE_Heathcare  USE_CASE_Other  \
# 0                           0                   0               0
# 1                           0                   0               0
# 2                           0                   0               0
# 3                           0                   0               0
# 4                           0                   1               0
# ...                       ...                 ...             ...
# 34294                       0                   0               0
# 34295                       0                   0               0
# 34296                       0                   0               0
# 34297                       0                   0               0
# 34298                       0                   0               0
#
#        USE_CASE_Preservation  USE_CASE_ProductDev  ORGANIZATION_Association  \
# 0                          0                    1                         1
# 1                          1                    0                         0
# 2                          0                    1                         1
# 3                          1                    0                         0
# 4                          0                    0                         0
# ...                      ...                  ...                       ...
# 34294                      0                    1                         1
# 34295                      0                    1                         1
# 34296                      1                    0                         1
# 34297                      0                    1                         1
# 34298                      1                    0                         0
#
#        ORGANIZATION_Co-operative  ORGANIZATION_Corporation  \
# 0                              0                         0
# 1                              1                         0
# 2                              0                         0
# 3                              0                         0
# 4                              0                         0
# ...                          ...                       ...
# 34294                          0                         0
# 34295                          0                         0
# 34296                          0                         0
# 34297                          0                         0
# 34298                          1                         0
#
#        ORGANIZATION_Trust  INCOME_AMT_0  INCOME_AMT_1-9999  \
# 0                       0             1                  0
# 1                       0             0                  1
# 2                       0             1                  0
# 3                       1             0                  0
# 4                       1             0                  0
# ...                   ...           ...                ...
# 34294                   0             1                  0
# 34295                   0             1                  0
# 34296                   0             1                  0
# 34297                   0             1                  0
# 34298                   0             0                  0
#
#        INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  INCOME_AMT_10M-50M  \
# 0                           0                         0                   0
# 1                           0                         0                   0
# 2                           0                         0                   0
# 3                           1                         0                   0
# 4                           0                         1                   0
# ...                       ...                       ...                 ...
# 34294                       0                         0                   0
# 34295                       0                         0                   0
# 34296                       0                         0                   0
# 34297                       0                         0                   0
# 34298                       0                         0                   0
#
#        INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  INCOME_AMT_50M+  \
# 0                     0                       0                0
# 1                     0                       0                0
# 2                     0                       0                0
# 3                     0                       0                0
# 4                     0                       0                0
# ...                 ...                     ...              ...
# 34294                 0                       0                0
# 34295                 0                       0                0
# 34296                 0                       0                0
# 34297                 0                       0                0
# 34298                 1                       0                0
#
#        INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0                      0                         1                         0
# 1                      0                         1                         0
# 2                      0                         1                         0
# 3                      0                         1                         0
# 4                      0                         1                         0
# ...                  ...                       ...                       ...
# 34294                  0                         1                         0
# 34295                  0                         1                         0
# 34296                  0                         1                         0
# 34297                  0                         1                         0
# 34298                  0                         1                         0
#
# [34299 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays

X = transformed_df.drop(columns = 'IS_SUCCESSFUL')
y = transformed_df['IS_SUCCESSFUL']

# %%
# Split the preprocessed data into a training and testing dataset

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 75)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((25724, 43), (8575, 43), (25724,), (8575,))

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=43))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=30, activation="tanh"))

# 10 more hidden layers
for i in range(10):
    nn_model.add(tf.keras.layers.Dense(units=30, activation="relu"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 30)                930
#
#  dense_3 (Dense)             (None, 30)                930
#
#  dense_4 (Dense)             (None, 30)                930
#
#  dense_5 (Dense)             (None, 30)                930
#
#  dense_6 (Dense)             (None, 30)                930
#
#  dense_7 (Dense)             (None, 30)                930
#
#  dense_8 (Dense)             (None, 30)                930
#
#  dense_9 (Dense)             (None, 30)                930
#
#  dense_10 (Dense)            (None, 30)                930
#
#  dense_11 (Dense)            (None, 30)                930
#
#  dense_12 (Dense)            (None, 1)                 31
#
# =================================================================
# Total params: 15,281
# Trainable params: 15,281
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
nn_model

# %%
# Train the model

fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50, verbose = 1)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 1s 841us/step - loss: 0.5756 - accuracy: 0.7156
# Epoch 2/50
# 804/804 [==============================] - 1s 837us/step - loss: 0.5584 - accuracy: 0.7249
# Epoch 3/50
# 804/804 [==============================] - 1s 911us/step - loss: 0.5556 - accuracy: 0.7265
# Epoch 4/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5551 - accuracy: 0.7271
# Epoch 5/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5536 - accuracy: 0.7244
# Epoch 6/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5520 - accuracy: 0.7280
# Epoch 7/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5511 - accuracy: 0.7269
# Epoch 8/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5520 - accuracy: 0.7277
# Epoch 9/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5507 - accuracy: 0.7295
# Epoch 10/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5495 - accuracy: 0.7297
# Epoch 11/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5486 - accuracy: 0.7277
# Epoch 12/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5484 - accuracy: 0.7280
# Epoch 13/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5478 - accuracy: 0.7297
# Epoch 14/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5470 - accuracy: 0.7325: 0s - loss: 0.5479 - accu
# Epoch 15/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5480 - accuracy: 0.7301
# Epoch 16/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5475 - accuracy: 0.7300
# Epoch 17/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5459 - accuracy: 0.7309
# Epoch 18/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5464 - accuracy: 0.7314
# Epoch 19/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5466 - accuracy: 0.7302
# Epoch 20/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5452 - accuracy: 0.7321
# Epoch 21/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5453 - accuracy: 0.7315
# Epoch 22/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5450 - accuracy: 0.7318
# Epoch 23/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5455 - accuracy: 0.7310
# Epoch 24/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5458 - accuracy: 0.7319
# Epoch 25/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5444 - accuracy: 0.7326
# Epoch 26/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5444 - accuracy: 0.7334
# Epoch 27/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5446 - accuracy: 0.7322
# Epoch 28/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5437 - accuracy: 0.7305
# Epoch 29/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5450 - accuracy: 0.7309
# Epoch 30/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5438 - accuracy: 0.7317
# Epoch 31/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5442 - accuracy: 0.7338
# Epoch 32/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5435 - accuracy: 0.7331
# Epoch 33/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5432 - accuracy: 0.7334
# Epoch 34/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5432 - accuracy: 0.7343
# Epoch 35/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5426 - accuracy: 0.7336
# Epoch 36/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5431 - accuracy: 0.7343
# Epoch 37/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5422 - accuracy: 0.7351
# Epoch 38/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5428 - accuracy: 0.7343
# Epoch 39/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5420 - accuracy: 0.7351
# Epoch 40/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5429 - accuracy: 0.7334
# Epoch 41/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5414 - accuracy: 0.7349
# Epoch 42/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5414 - accuracy: 0.7346
# Epoch 43/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5420 - accuracy: 0.7320
# Epoch 44/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5403 - accuracy: 0.7359
# Epoch 45/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5411 - accuracy: 0.7347
# Epoch 46/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5408 - accuracy: 0.7344
# Epoch 47/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5408 - accuracy: 0.7340
# Epoch 48/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5415 - accuracy: 0.7345
# Epoch 49/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5404 - accuracy: 0.7355
# Epoch 50/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5399 - accuracy: 0.7361

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5490 - accuracy: 0.7370 - 321ms/epoch - 1ms/step
# Loss: 0.5490366220474243, Accuracy: 0.7370262145996094

# %%
# Export our model to HDF5 file

nn_model.save('../Resources/AlphabetSoupCharity_OptimizationAttempt1.h5')

# %%
# pip install pyyaml h5py

# %%
history_df = pd.DataFrame(fit_model.history)

history_df.index += 1

history_df.plot(y='loss', color = 'red')
plt.xlabel('Epoch Index')
plt.ylabel('Loss')
plt.title('Optimization 1 Training Loss Graph')
plt.legend (loc = 'center right')
plt.savefig("../Images/A1_Model_Loss.png")


history_df.plot(y='accuracy', color = 'green')
plt.xlabel('Epoch Index')
plt.ylabel('Accuracy')
plt.title('Optimization 1 Training Accuracy Graph')
plt.legend (loc = 'center right')
plt.savefig("../Images/A1_Model_Accuracy.png")


plt.figure(figsize = (15,5))
plt.plot(history_df['loss'], color='red', label='loss', )
plt.plot(history_df['accuracy'], color='green', label='accuracy')
plt.xlim([0, 52])
plt.ylim([0.45, 0.8])
plt.xlabel('Epoch Index')
plt.ylabel('Accuracy/Loss')
plt.title('Model Optimization 1 Training Accuracy/Loss Graph')
plt.legend(loc = 'center right')
plt.savefig("../Images/A1_ModelAccuracy_Loss.png")
plt.show()
